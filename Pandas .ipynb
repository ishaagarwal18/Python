# %% [markdown]
# # Pandas

# %% [markdown]
# ##### Series

# %%
import pandas as pd

# %%
x=[10,20,30,40]
y=pd.Series(x)
print(y)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
x=["RCB","CSK","DC"]
y=pd.Series(x)
print(y)
# Out:
# 0    RCB
# 1    CSK
# 2     DC
# dtype: object

# %%
x={
    "a":1,
    "b":2,
    "c":3
}
y=pd.Series(x)
print(y)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
import numpy as np

# %%
ar=np.array([1,2,3,4,5])
y=pd.Series(ar)
print(y)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int32

# %%
a=range(5)
b=pd.Series(a)
print(b)
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
import random

# %%
x=np.random.randint(10)

# %%
name=["Virat","Sanju","Dhoni","Rohit"]
run=[83,89,23,67]
data=pd.Series(name,index=run,name="Score")
print(data)
# Out:
# 83    Virat
# 89    Sanju
# 23    Dhoni
# 67    Rohit
# Name: Score, dtype: object

# %%
pwd
# Out:
# 'C:\\Users\\LJENG'

# %%
f=pd.read_csv("batsman_runs_ipl.csv")
df=pd.DataFrame(f)
df
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['batter', 'batsman_run'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 605 entries, 0 to 604
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   batter       605 non-null    object
#  1   batsman_run  605 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 9.6+ KB

# %%
df.shape
# Out:
# (605, 2)

# %%
df.head()
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25

# %%
df.tail()
# Out:
#             batter  batsman_run
# 600     Yash Dayal            0
# 601  Yashpal Singh           47
# 602    Younis Khan            3
# 603   Yuvraj Singh         2754
# 604         Z Khan          117

# %%
l=[[1,2,3],[4,5,6],[7,8,9]]
d=pd.DataFrame(l)
d
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.set_index(df["batsman_run"],inplace=True)

# %%
df
# Out:
#                      batter  batsman_run
# batsman_run
# 280          A Ashish Reddy          280
# 161                A Badoni          161
# 4                A Chandila            4
# 53                 A Chopra           53
# 25              A Choudhary           25
# ...                     ...          ...
# 0                Yash Dayal            0
# 47            Yashpal Singh           47
# 3               Younis Khan            3
# 2754           Yuvraj Singh         2754
# 117                  Z Khan          117
#
# [605 rows x 2 columns]

# %%
import pandas as pd

# %%
f=pd.read_csv("ipl-matches.csv")

# %%
df=pd.DataFrame(f)

# %%
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df[df["SuperOver"]=="Y"].shape[0]
# Out:
# 14

# %%
df[(df["WinningTeam"]=="Chennai Super Kings") & (df["City"]=="Kolkata")].shape[0]
# Out:
# 5

# %%
df[(df["WinningTeam"]=="Gujarat Titans") & (df["TossWinner"]=="Gujarat Titans") & (df["TossDecision"]=="bat")].shape[0]
# Out:
# 2

# %%
df["Player_of_Match"].unique()
# Out:
# array(['HH Pandya', 'JC Buttler', 'RM Patidar', 'DA Miller',
#        'Harpreet Brar', 'JJ Bumrah', 'R Ashwin', 'V Kohli', 'Q de Kock',
#        'RA Tripathi', 'SN Thakur', 'TA Boult', 'WP Saha', 'AD Russell',
#        'JM Bairstow', 'DR Sams', 'MR Marsh', 'Shubman Gill', 'DP Conway',
#        'PWH de Silva', 'Avesh Khan', 'YBK Jaiswal', 'TH David',
#        'DA Warner', 'HV Patel', 'K Rabada', 'RK Singh', 'RD Gaikwad',
#        'Mohsin Khan', 'SA Yadav', 'R Tewatia', 'KH Pandya',
#        'Kuldeep Yadav', 'Umran Malik', 'R Parag', 'S Dhawan', 'KL Rahul',
#        'M Jansen', 'Rashid Khan', 'Mukesh Choudhary', 'F du Plessis',
#        'YS Chahal', 'KD Karthik', 'MA Agarwal', 'S Dube', 'KS Williamson',
#        'Anuj Rawat', 'Abhishek Sharma', 'PJ Cummins', 'LS Livingstone',
#        'LH Ferguson', 'UT Yadav', 'E Lewis', 'SV Samson',
#        'Mohammed Shami', 'OF Smith', 'VR Iyer', 'SP Narine', 'KS Bharat',
#        'Ishan Kishan', 'Shivam Mavi', 'NM Coulter-Nile', 'AR Patel',
# ...

# %%
df[(df["Player_of_Match"]=="MS Dhoni") & ((df["Team1"]=="Mumbai Indians") | (df["Team2"]=="Mumbai Indians"))].shape[0]
# Out:
# 1

# %%
df["Player_of_Match"]
# Out:
# 0          HH Pandya
# 1         JC Buttler
# 2         RM Patidar
# 3          DA Miller
# 4      Harpreet Brar
#            ...
# 945        DJ Hussey
# 946       MV Boucher
# 947      MF Maharoof
# 948       MEK Hussey
# 949      BB McCullum
# Name: Player_of_Match, Length: 950, dtype: object

# %%
df[df["WinningTeam"]=="Gujarat Titans"].shape[0]
# Out:
# 12

# %%
 import pandas as pd
data = {
    "EmpID":[101,102,103,104,105],
    "Dept":["IT","HR","IT","Finance","HR"],
    "Salary":[60000,45000,80000,75000,50000],
    "Age":[25,32,29,41,28]
}

# %%
df=pd.DataFrame(data)

# %%
df.sort_values(by="Dept")
# Out:
#    EmpID     Dept  Salary  Age
# 3    104  Finance   75000   41
# 1    102       HR   45000   32
# 4    105       HR   50000   28
# 0    101       IT   60000   25
# 2    103       IT   80000   29

# %%
df.sort_values(by="Salary",ascending=False,inplace=True)

# %%
df
# Out:
#    EmpID     Dept  Salary  Age
# 2    103       IT   80000   29
# 3    104  Finance   75000   41
# 0    101       IT   60000   25
# 4    105       HR   50000   28
# 1    102       HR   45000   32

# %%
df.sort_index(ascending=False)
# Out:
#    EmpID     Dept  Salary  Age
# 4    105       HR   50000   28
# 3    104  Finance   75000   41
# 2    103       IT   80000   29
# 1    102       HR   45000   32
# 0    101       IT   60000   25

# %%
import pandas as pd
df = pd.DataFrame({
    "Student":["A","B","C","D"],
    "Math":[70,45,90,60],
    "Science":[75,40,85,55]
})

# %%
df
# Out:
#   Student  Math  Science
# 0       A    70       75
# 1       B    45       40
# 2       C    90       85
# 3       D    60       55

# %%
df["Grade"]=0

# %%
df
# Out:
#   Student  Math  Science  Grade
# 0       A    70       75      0
# 1       B    45       40      0
# 2       C    90       85      0
# 3       D    60       55      0

# %%
df.groupby("Student")[["Math","Science"]].sum()
# Out:
#          Math  Science
# Student
# A          70       75
# B          45       40
# C          90       85
# D          60       55

# %%
df[["Math","Science"]].sum()
# Out:
# Math       265
# Science    255
# dtype: int64

# %%
import pandas as pd
df1 = pd.DataFrame({
    "ID":[1,2,3],
    "Name":["A","B","C"]
})
df2 = pd.DataFrame({
    "ID":[2,3,4],
    "Marks":[80,90,70]
})

# %%
df1
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C

# %%
df2
# Out:
#    ID  Marks
# 0   2     80
# 1   3     90
# 2   4     70

# %%
df3=pd.concat([df1,df2],join="outer")

# %%
pd.concat([df1,df2],join="inner")
# Out:
#    ID
# 0   1
# 1   2
# 2   3
# 0   2
# 1   3
# 2   4

# %%
pd.concat([df1,df2])
# Out:
#    ID Name  Marks
# 0   1    A    NaN
# 1   2    B    NaN
# 2   3    C    NaN
# 0   2  NaN   80.0
# 1   3  NaN   90.0
# 2   4  NaN   70.0

# %%
df3.isnull().sum()
# Out:
# ID       0
# Name     3
# Marks    3
# dtype: int64

# %%
f=pd.read_csv("ipl-matches.csv")

# %%
df=pd.DataFrame(f)
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df[(df["WinningTeam"]=="Gujarat Titans") & (df["SuperOver"]=="Y")].shape[0]
# Out:
# 0

# %%
df[(df["WinningTeam"]=="Royal Challengers Bangalore")&((df["Team1"]=="Kolkata Knight Riders")|(df["Team2"]=="Kolkata Knight Riders"))].shape[0]
# Out:
# 14

# %%
df[df["TossWinner"]==df["WinningTeam"]].shape[0]
# Out:
# 489

# %%
df["method"].unique()
# Out:
# array([nan, 'D/L'], dtype=object)

# %%
df[(df["method"]=="D/L") & (df["WonBy"]=="Wickets")].shape[0]
# Out:
# 8

# %%
df[(df["TossWinner"]=="Rajasthan Royals")&(df["WinningTeam"]=="Rajasthan Royals")].shape[0]
# Out:
# 49

# %%
df[(df["Player_of_Match"]=="V Kohli")&((df["Team1"]=="Chennai Super Kings")|(df["Team2"]=="Chennai Super Kings"))].shape[0]
# Out:
# 2

# %%
df[(df["City"]=="Dubai")&(df["MatchNumber"]=="Final")]["TossWinner"]
# Out:
# 74    Kolkata Knight Riders
# Name: TossWinner, dtype: object

# %%
df[(df["MatchNumber"]=="Final")& ((df["Team1"]=="Kolkata Knight Riders")|(df["Team2"]=="Kolkata Knight Riders"))&
   (df["TossWinner"]=="Kolkata Knight Riders")&(df["TossDecision"]=="field")].shape[0]
# Out:
# 2

# %%
df.corr??
