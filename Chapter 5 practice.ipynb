# %%
l=[1,2,3,4,5]
l.insert(2,9)
print(l)
# Out:
# [1, 2, 9, 3, 4, 5]

# %%
l.remove(2)

# %%
print(l)
# Out:
# [1, 9, 3, 4, 5]

# %%
l.extend(7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 l.extend(7)
#
# TypeError: 'int' object is not iterable

# %%
l=[4,5,6,7]
l.insert(2,100)

# %%
print(l)
# Out:
# [4, 5, 100, 6, 7]

# %%
l[2:] =[12,13,14]
print(l)
# Out:
# [4, 5, 12, 13, 14]

# %%
Tup=[2,3,4,[]]
Tup[-1].extend(range(5,35,5))
print(Tup)
Tup[-1].append([10,20])
print(Tup)
Tup[-1][-1].append([100,200])
print(Tup)
print(len(Tup))
print(len(Tup[3]))
print(len(Tup[-1][-1]))
print(Tup[-1][-2])
# Out:
# [2, 3, 4, [5, 10, 15, 20, 25, 30]]
# [2, 3, 4, [5, 10, 15, 20, 25, 30, [10, 20]]]
# [2, 3, 4, [5, 10, 15, 20, 25, 30, [10, 20, [100, 200]]]]
# 4
# 7
# 3
# 30

# %%
a={8:"D",2:"B",3:"C"}
print(a.get(1,4))
# Out:
# 4

# %%
a.get??
# Out:
# Signature: a.get(key, default=None, /)
# Docstring: Return the value for key if key is in the dictionary, else default.
# Type:      builtin_function_or_method

# %%
l1=[]
l1.append([1,[2,3],4])
print(l1)
l1.axtend([7,8,9])
print(l1)
print(l1[0][1][1]+l1[2])
# Out:
# [[1, [2, 3], 4]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 4
#       2 l1.append([1,[2,3],4])
#       3 print(l1)
# ----> 4 l1.axtend([7,8,9])
#       5 print(l1)
#       6 print(l1[0][1][1]+l1[2])
#
# AttributeError: 'list' object has no attribute 'axtend'

# %%
l=[]
l.append([1,2,3])

# %%
print(l)
# Out:
# [[1, 2, 3]]

# %%
numbers = [1, 2, 3, 4]
numbers.append([5,6,7,8])
print(len(numbers))
# Out:
# 5

# %%
x = [1, 2, 3]
y = [7, 8, 9]
x.extend(y)
print(x)
# Out:
# [1, 2, 3, 7, 8, 9]

# %%
L1 = []
L1.append([1, [2, 3], 4])
l1.extend([7, 8, 9])
print(L1[0][1][1] + L1[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 4
#       2 L1.append([1, [2, 3], 4])
#       3 l1.extend([7, 8, 9])
# ----> 4 print(L1[0][1][1] + L1[2])
#
# IndexError: list index out of range
