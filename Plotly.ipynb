# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import pandas as pd

# %%
data={"maths":[80,70,60,50],"python":[100,20,80,70],"sci":[80,77,90,60]}
df=pd.DataFrame(data)
df
# Out:
#    maths  python  sci
# 0     80     100   80
# 1     70      20   77
# 2     60      80   90
# 3     50      70   60

# %%
c=df.corr()

# %%
c
# Out:
#            maths    python       sci
# maths   1.000000  0.113796  0.486453
# python  0.113796  1.000000  0.170781
# sci     0.486453  0.170781  1.000000

# %%
sns.heatmap(c,linewidths=3,linecolor="black",annot=True,cmap="coolwarm")
plt.show()

# %%
import pandas as pd
df = pd.DataFrame({
    "E":["A","B","C","D","E"],
    "D":["IT","HR","IT","Finance","HR"],
    "S":[50000,40000,70000,80000,45000]
})

# %%
df
# Out:
#    E        D      S
# 0  A       IT  50000
# 1  B       HR  40000
# 2  C       IT  70000
# 3  D  Finance  80000
# 4  E       HR  45000

# %%
sns.boxplot??
# Out:
# Signature:
# sns.boxplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     order=None,
#     hue_order=None,
#     orient=None,
#     color=None,
#     palette=None,
#     saturation=0.75,
#     fill=True,
#     dodge='auto',
#     width=0.8,
#     gap=0,
#     whis=1.5,
#     linecolor='auto',
#     linewidth=None,
#     fliersize=None,
#     hue_norm=None,
#     native_scale=False,
#     log_scale=None,
#     formatter=None,
#     legend='auto',
#     ax=None,
#     **kwargs,
# )
# Docstring:
# Draw a box plot to show distributions with respect to categories.
#
# A box plot (or box-and-whisker plot) shows the distribution of quantitative
# data in a way that facilitates comparisons between variables or across
# levels of a categorical variable. The box shows the quartiles of the
# dataset while the whiskers extend to show the rest of the distribution,
# except for points that are determined to be "outliers" using a method
# ...

# %%
sns.boxplot(x="E",y="S",hue="D",data=df)
plt.show()

# %%
# !pip install plotly --user

# %%
import plotly.express as px
import plotly.io as pio
pio.renderers.default="plotly_mimetype"

# %%
import pandas as pd
df = pd.DataFrame({
    "Gender":["M","F","M","F","M","F"],
    "Dept":["IT","IT","HR","HR","Finance","Finance"],
    "Salary":[50000,-55000,40000,70000,80000,45000],
    "ex":["1","2","3","4","5","6"]
})
df
# Out:
#   Gender     Dept  Salary ex
# 0      M       IT   50000  1
# 1      F       IT  -55000  2
# 2      M       HR   40000  3
# 3      F       HR   70000  4
# 4      M  Finance   80000  5
# 5      F  Finance   45000  6

# %%
fig=px.bar(df,x="Dept",y="Salary")
fig.show()

# %%
fig=px.bar(df,x="Dept",y="Salary",barmode="group",color="Gender")
fig.show()

# %%
fig=px.bar(df,x="Dept",y="Salary",barmode="relative",color="Gender")
fig.show()

# %%
fig=px.bar(df,x="Dept",y="Salary",barmode="group",color="Gender",width=800,height=500,
          hover_data=["ex"],color_discrete_map={"M":"yellow","F":"black"})
fig.show()

# %%
df
# Out:
#   Gender     Dept  Salary ex
# 0      M       IT   50000  1
# 1      F       IT  -55000  2
# 2      M       HR   40000  3
# 3      F       HR   70000  4
# 4      M  Finance   80000  5
# 5      F  Finance   45000  6

# %%
fig=px.scatter(df,x="Salary",y="ex")
fig.show()

# %%
data={
    "h":[2,3,4,5,6,7],
    "marks":[40,50,60,65,70,80],
    "Gender":["M","F","M","F","M","F"],
    "name":[40,50,60,65,70,80],
    "D":["IT","HR","IT","Finance","HR","Finance"]
}
df=pd.DataFrame(data)

# %%
df
# Out:
#    h  marks Gender  name        D
# 0  2     40      M    40       IT
# 1  3     50      F    50       HR
# 2  4     60      M    60       IT
# 3  5     65      F    65  Finance
# 4  6     70      M    70       HR
# 5  7     80      F    80  Finance

# %%
fig=px.scatter(df,x="h",y="marks",color="Gender",title="Marksheet",symbol="Gender",size="marks",hover_data=["D","name"],facet_col="D")
fig.show()

# %%
fig=px.scatter_3d(df,x="h",y="marks",z="Gender",color="Gender",title="Marksheet",symbol="Gender",size="marks",hover_data=["D","name"],)
fig.show()

# %%
fig=px.line(df,x="h",y="Gender",markers=True)
fig.show()

# %%
fig=px.pie(df,values="h",names="D")
fig.update_traces(pull=[0.1,0,0],textinfo="percent+label")
fig.show()

# %% [markdown]
# ## Networkx

# %%
import networkx as nx

# %%
import matplotlib.pyplot as plt

# %%
g=nx.Graph() # made a graph
g.add_node(1) # make a node
nx.draw_networkx(g)  # for showing

# %%
g.add_node("D")
g.add_node("H")
g.add_node("E")
g.add_node("S")

# %%
nx.draw_networkx(g)

# %%
g.add_nodes_from([10,20,30,40,50])

# %%
nx.draw_networkx(g)

# %%
g=nx.Graph()
g.add_node(1)
g.add_nodes_from([10,20,30,40,50])
g.add_edge(1,10)
g.add_edge(40,10)
g.add_edge(1,20)
g.add_edge(50,10)
g.add_edge(30,10)
g.add_edges_from([(40,1),(30,1)])
# g.clear_edges()
print(g.has_edge(40,20))


nx.draw_networkx(g,node_size=850,node_color="deeppink",width=4,edge_color="blue")
# Out:
# False

# %%
g=nx.DiGraph()
g.add_node(1)
g.add_nodes_from([10,20,30,40,50])
g.add_edge(1,10)
g.add_edge(40,10)
g.add_edge(1,20)
g.add_edge(50,10)
g.add_edge(30,10)
g.add_edges_from([(40,1),(30,1)])

nx.draw_networkx(g,node_size=850,node_color="red",width=4,edge_color="blue")

# %%
g.has_edge??
# Out:
# Signature: g.has_edge(u, v)
# Source:
#     def has_edge(self, u, v):
#         """Returns True if the edge (u, v) is in the graph.
#
#         This is the same as `v in G[u]` without KeyError exceptions.
#
#         Parameters
#         ----------
#         u, v : nodes
#             Nodes can be, for example, strings or numbers.
#             Nodes must be hashable (and not None) Python objects.
#
#         Returns
#         -------
#         edge_ind : bool
#             True if edge is in the graph, False otherwise.
#
#         Examples
#         --------
#         >>> G = nx.path_graph(4)  # or DiGraph, MultiGraph, MultiDiGraph, etc
#         >>> G.has_edge(0, 1)  # using two nodes
#         True
#         >>> e = (0, 1)
#         >>> G.has_edge(*e)  #  e is a 2-tuple (u, v)
#         True
#         >>> e = (0, 1, {"weight": 7})
#         >>> G.has_edge(*e[:2])  # e is a 3-tuple (u, v, data_dictionary)
#         True
#
#         The following syntax are equivalent:
#
# ...

# %%
insta={
    "p1":[0,1,1,0,1],
    "p2":[0,0,1,0,1],
    "p3":[1,1,0,1,1],
    "p4":[1,1,1,0,0],
    "p5":[1,1,0,0,0]
}
g=nx.DiGraph()
x=insta.keys()
g.add_nodes_from(x)
for i,j in insta.items():
    for k,l in enumerate(j):
        if l==1:
            g.add_edge(i,f"p{k+1}")

nx.draw_networkx(g)

# %%
g=nx.Graph()
g.add_node(1)
g.add_nodes_from([10,20,30,40,50])
g.add_edge(1,10)
g.add_edge(40,10)
g.add_edge(1,20)
g.add_edge(50,10)
g.add_edge(30,10)
g.add_edges_from([(40,1),(30,1)])

nx.draw(g)

# %%
g=nx.Graph()
g.add_node(1)
g.add_nodes_from([10,20,30,40,50])
g.add_edge(1,10)
g.add_edge(40,10)
g.add_edge(1,20)
g.add_edge(50,10)
g.add_edge(30,10)
g.add_edges_from([(40,1),(30,1)])

nx.draw(g,with_labels=True)
