# %% [markdown]
# # Chapter 6 File Handling
# - A file is a collection of data, and it is manipulated using a Python object.
# - Files can be read, written, or appended, and only one mode can be performed at a time.
# Would you like to add more points or have me explain file operations in Python?

# %%
# %%writefile sample.txt
# this
# is
# python
# file
# Out:
# Writing sample.txt

# %% [markdown]
# #### WAP to write hello 100 times into a file named hello.txt

# %%
file=open("hello.txt","w")
file.write("hello\n"*100)
file.close()

# %% [markdown]
# #### WAP to take a name and age of customer and write it into the file

# %%
name=input("Enter name of customer : ")
age=input("Enter age of customer : ")
with open("Customer.txt","w") as f:
    f.write(name+"\n")
    f.write(age+"\n")
# Out:
# Enter name of customer :  Ish
# Enter age of customer :  19

# %%
pwd
# Out:
# 'C:\\Users\\yasha'
