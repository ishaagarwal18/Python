# %%
import pandas as pd
import numpy as np
df=pd.DataFrame([[0,1.0,2.0,np.nan,5],[2.0,0,1.0,5.0,np.nan],[5.0,0,1.0,np.nan,5.0]])
df
# Out:
#      0    1    2    3    4
# 0  0.0  1.0  2.0  NaN  5.0
# 1  2.0  0.0  1.0  5.0  NaN
# 2  5.0  0.0  1.0  NaN  5.0

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, 3, 4]
# Index: []

# %%
df
# Out:
#      0    1    2    3    4
# 0  0.0  1.0  2.0  NaN  5.0
# 1  2.0  0.0  1.0  5.0  NaN
# 2  5.0  0.0  1.0  NaN  5.0

# %%
print(df.loc[1,3])
# Out:
# 5.0

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame([[0,1,2,np.nan,5],[2,0,1,5,np.nan],[5,0,1,np.nan,5],[2,0,1,np.nan,np.nan]])
# df=df.drop_duplicates(subset=[1,2])
df
# Out:
#    0  1  2    3    4
# 0  0  1  2  NaN  5.0
# 1  2  0  1  5.0  NaN
# 2  5  0  1  NaN  5.0
# 3  2  0  1  NaN  NaN

# %%
df=df.drop_duplicates(subset=[1,2])
df
# Out:
#    0  1  2    3    4
# 0  0  1  2  NaN  5.0
# 1  2  0  1  5.0  NaN

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({"a":[1,2,np.nan,3,4],"b":[1,5,np.nan,2,1]})
# df=df.drop_duplicates(subset="b")
# df.dropna()
df
# Out:
#      a    b
# 0  1.0  1.0
# 1  2.0  5.0
# 2  NaN  NaN
# 3  3.0  2.0
# 4  4.0  1.0

# %%
df=df.drop_duplicates(subset="b")

df
# Out:
#      a    b
# 0  1.0  1.0
# 1  2.0  5.0
# 2  NaN  NaN
# 3  3.0  2.0

# %%
df1=pd.DataFrame({"A":[1,2]})
df2=pd.DataFrame({"A":[3,4]})
result=pd.concat([df1,df2],ignore_index=True)
result
# Out:
#    A
# 0  1
# 1  2
# 2  3
# 3  4

# %%
import pandas as pd
df1 = pd.DataFrame({
 "ID":[1,2,3],
 "Name":["A","B","C"]
})
df2 = pd.DataFrame({
 "ID":[2,3,4],
 "Marks":[80,90,70]
})
result = pd.merge(df1, df2, how="inner", on="ID")

# %%
result
# Out:
#    ID Name  Marks
# 0   2    B     80
# 1   3    C     90

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({
 "A":[1,2,3],
 "B":[4,5,6]
})
result = df.apply(sum, axis=0)
print(result["A"])
# Out:
# 6

# %%
import pandas as pd
df = pd.DataFrame({
 "Dept":["IT","HR","IT","Finance"]
})
groups = df.groupby("Dept").groups
print(groups["IT"])
# Out:
# Index([0, 2], dtype='int64')

# %%
df1 = pd.DataFrame({"A":[1,2]}, index=[0,1])
df2 = pd.DataFrame({"A":[3,4]}, index=[1,2])
result = pd.concat([df1,df2])
print(result.loc[2]["A"])
# Out:
# 4

# %%
result
# Out:
#    A
# 0  1
# 1  2
# 1  3
# 2  4

# %%
import pandas as pd
df1 = pd.DataFrame({"A":[1,2,3]})
df2 = pd.DataFrame({"B":[4,5]})
result = pd.concat([df1,df2], axis=1)
print(result.isnull().sum().sum())
# Out:
# 1

# %%
result
# Out:
#    A    B
# 0  1  4.0
# 1  2  5.0
# 2  3  NaN

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "name": ["William","Emma","Sofia","Markus","Edward","Thomas","Ethan",np.nan,"Arun","Anika","Paulo"],
    "region": [np.nan,"North","East",np.nan,"West","West","South",np.nan,"West","East","South"],
    "sales": [50000,52000,np.nan,np.nan,42000,72000,49000,np.nan,67000,65000,67000],
    "expenses": [42000,43000,np.nan,np.nan,38000,39000,42000,np.nan,39000,50000,45000]
})

# %%
df
# Out:
#        name region    sales  expenses
# 0   William    NaN  50000.0   42000.0
# 1      Emma  North  52000.0   43000.0
# 2     Sofia   East      NaN       NaN
# 3    Markus    NaN      NaN       NaN
# 4    Edward   West  42000.0   38000.0
# 5    Thomas   West  72000.0   39000.0
# 6     Ethan  South  49000.0   42000.0
# 7       NaN    NaN      NaN       NaN
# 8      Arun   West  67000.0   39000.0
# 9     Anika   East  65000.0   50000.0
# 10    Paulo  South  67000.0   45000.0

# %%
print(df.dropna(inplace=True))
# Out:
# None

# %%
df.reset_index()
# Out:
#    index    name region    sales  expenses
# 0      1    Emma  North  52000.0   43000.0
# 1      4  Edward   West  42000.0   38000.0
# 2      5  Thomas   West  72000.0   39000.0
# 3      6   Ethan  South  49000.0   42000.0
# 4      8    Arun   West  67000.0   39000.0
# 5      9   Anika   East  65000.0   50000.0
# 6     10   Paulo  South  67000.0   45000.0

# %% [markdown]
# ## PB 59
# ```
# Consider the following data:
# data = {
#  "A": ["TeamA", "TeamB", "TeamB", "TeamC", "TeamA"],
#  "B": [50, 40, 40, 30, 50],
#  "C": [True, False, False, False, True]
# }
# Convert this to a Pandas DataFrame and remove duplicate rows from it. Reset index v
# ```alues.

# %%
data = {
 "A": ["TeamA", "TeamB", "TeamB", "TeamC", "TeamA"],
 "B": [50, 40, 40, 30, 50],
 "C": [True, False, False, False, True]
}
df=pd.DataFrame(data)
df.drop_duplicates(inplace=True)
df
# Out:
#        A   B      C
# 0  TeamA  50   True
# 1  TeamB  40  False
# 3  TeamC  30  False

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#        A   B      C
# 0  TeamA  50   True
# 1  TeamB  40  False
# 2  TeamC  30  False

# %% [markdown]
# ## PB 68
# ```
# import pandas as pd
# data = {
#  "EmpID":[101,102,103,104,105],
#  "Dept":["IT","HR","IT","Finance","HR"],
#  "Salary":[60000,45000,80000,75000,50000],
#  "Age":[25,32,29,41,28]
# }
# df = pd.DataFrame(data)
# Sort employees by Dept (Ascending) and Salary (Descending).
# After sorting, sort the index in descending order.
# Display the final
# ```DataFrame.

# %%
import pandas as pd
data = {
 "EmpID":[101,102,103,104,105],
 "Dept":["IT","HR","IT","Finance","HR"],
 "Salary":[60000,45000,80000,75000,50000],
 "Age":[25,32,29,41,28]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#    EmpID     Dept  Salary  Age
# 0    101       IT   60000   25
# 1    102       HR   45000   32
# 2    103       IT   80000   29
# 3    104  Finance   75000   41
# 4    105       HR   50000   28

# %%
df.sort_values(by=["Dept","Salary"],ascending=[True,False],inplace=True)

# %%
df
# Out:
#    EmpID     Dept  Salary  Age
# 3    104  Finance   75000   41
# 4    105       HR   50000   28
# 1    102       HR   45000   32
# 2    103       IT   80000   29
# 0    101       IT   60000   25

# %%
df.sort_index(ascending=False,inplace=True)

# %%
df
# Out:
#    EmpID     Dept  Salary  Age
# 4    105       HR   50000   28
# 3    104  Finance   75000   41
# 2    103       IT   80000   29
# 1    102       HR   45000   32
# 0    101       IT   60000   25

# %%
df
# Out:
#    EmpID     Dept  Salary  Age
# 4    105       HR   50000   28
# 3    104  Finance   75000   41
# 2    103       IT   80000   29
# 1    102       HR   45000   32
# 0    101       IT   60000   25

# %%
import matplotlib.pyplot as plt

# %%
pd.plotting.scatter_matrix(df)
plt.show()

# %%
pd.plotting.parallel_coordinates(df,"Dept")
plt.show()

# %%
pd.crosstab(df["Salary"],df["Age"])
# Out:
# Age     25  28  29  32  41
# Salary
# 45000    0   0   0   1   0
# 50000    0   1   0   0   0
# 60000    1   0   0   0   0
# 75000    0   0   0   0   1
# 80000    0   0   1   0   0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import plotly.express as px
import plotly.io as pio
pio.renderers.default="plotly_mimetype"

# %%
data ={
    "maths":[80,77,34,21,78],
    "physics":[79,80,85,79,93]
}
df=pd.DataFrame(data)
c=df.corr()
sns.heatmap(c,linecolor="black",cmap="coolwarm",linewidths=3)
plt.show()

# %%
import pandas as pd
data = {
 "EmpID":[101,102,103,104,105],
 "Dept":["IT","HR","IT","Finance","HR"],
 "Salary":[60000,45000,80000,75000,50000],
 "Age":[25,32,29,41,28]
}
df = pd.DataFrame(data)

# %%
sns.boxplot(x="EmpID",y="Salary",data=df,hue="Dept",linewidth=2)
# Out:
# <Axes: xlabel='EmpID', ylabel='Salary'>

# %%
data={
    "h":[2,3,4,5,6,7],
    "marks":[40,50,60,65,70,80],
    "Gender":["M","F","M","F","M","F"],
    "name":[40,50,60,65,70,80],
    "D":["IT","HR","IT","Finance","HR","Finance"]
}
df=pd.DataFrame(data)
df
# Out:
#    h  marks Gender  name        D
# 0  2     40      M    40       IT
# 1  3     50      F    50       HR
# 2  4     60      M    60       IT
# 3  5     65      F    65  Finance
# 4  6     70      M    70       HR
# 5  7     80      F    80  Finance

# %%
fig=px.bar(df,x="Gender",y="h")
fig.show()

# %%
data=pd.read_csv("https://raw.githubusercontent.com/kavit88/Data-Sets/main/temperatures.csv")
df=pd.DataFrame(data)
df
# Out:
#     New York  Los Angeles  Chicago        Date
# 0         30           70       20  01-05-2023
# 1         35           72       22  02-05-2023
# 2         28           68       18  03-05-2023
# 3         32           75       24  04-05-2023
# 4         33           73       21  05-05-2023
# 5         29           71       19  06-05-2023
# 6         31           74       23  07-05-2023
# 7         34           72       20  08-05-2023
# 8         30           70       22  09-05-2023
# 9         33           69       25  10-05-2023
# 10        32           76       20  11-05-2023
# 11        36           72       18  12-05-2023
# 12        31           68       23  13-05-2023
# 13        29           73       19  14-05-2023
# 14        32           75       24  15-05-2023
# 15        34           69       21  16-05-2023
# 16        30           71       18  17-05-2023
# 17        35           73       22  18-05-2023
# 18        28           67       20  19-05-2023
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
plt.figure()
df.boxplot()
plt.title("Temperature Distribution by City")
plt.ylabel("Temperature (°C)")
plt.xticks(rotation=30)
plt.show()

# %%
data=pd.read_csv("https://raw.githubusercontent.com/kavit88/Data-Sets/main/car_data.csv")
df=pd.DataFrame(data)
df

plt.figure()

plt.subplot(1,3,1)
plt.scatter(df["Horsepower"], df["Price"])
plt.xlabel("Horsepower")
plt.ylabel("Price")

plt.subplot(1,3,2)
plt.scatter(df["Mileage"], df["Price"])
plt.xlabel("Mileage")

plt.subplot(1,3,3)
plt.scatter(df["Weight"], df["Price"])
plt.xlabel("Weight")

plt.tight_layout()
plt.show()

# %%
df.corr()
# Out:
#                Price  Horsepower   Mileage    Weight
# Price       1.000000    0.995037 -0.973352  0.987126
# Horsepower  0.995037    1.000000 -0.966742  0.986031
# Mileage    -0.973352   -0.966742  1.000000 -0.976501
# Weight      0.987126    0.986031 -0.976501  1.000000

# %% [markdown]
# ##### PB63
# ```
# Use the file spotify.csv
# 1.Convert this file into a pandas Data Frame. (0.5 marks)
# 2.Display basic informaƟon like memory and data types for this data frame.
# (0.5 marks)
# 3.Display basic staƟsƟcs like mean, std, quarƟles, etc. for this data frame.
# (0.5 marks)
# 4.Create a correlaƟon table for the data frame and comment about what kind of correlaƟon is there between danceability and
# energy (0.5 marks)
# 5.Display first five rows for this data frame.(0.5 marks)
# 6.Display last five rows for this data frame. (0.5 marks)
# 7.Display the rows between 15 to 39 for this data frame. (0.5 marks)
# 8.Display the data only for last five rows and last five columns for this data frame. (0.5 marks)
# 9.Display the shape for this data frame. (0.5 marks)
# 10.Display the sum of NULL values for all the columns. (0.5 marks)
# 11.Remove first 3 columns from this Data Frame. (0.5 marks)
# 12.Remove first 10 rows from this Data Frame. (0.5 marks)
# 13.AŌer removing first 3 columns and first 10 rows from this data frame find outliers for the column popularity. (1 marks)
# 14.AŌer removing first 3 columns and first 10 rows from this data frame remove outliers for the column energy then display
# the data frame. (1 marks)
# 15.Display cross tabulaƟon between Ɵme_signature and track_genre for actual Da
# ```ta Frame. (1 marks)

# %% [markdown]
# ##### PB62,67
# ```
# Use the file ipl-matches.csv which contains data of all the IPL matches from year 2008 to 2022. Read this csv file and display the
# basic information like memory and data types for this data frame. Write python code for the following cases:
# 1. List out all matches gone in superover.
# 2. How Many Matches won by Chennai Super Kings at Kolkata.
# 3. In How Many Matches MS Dhoni is Player of Match Vs Mumbai Indians.
# 4. Display list of all matches in which Gujarat Titans won the Toss and Elected to Bat and won the match.
# 5. Display list of all matches won by Gujarat Ti1.How many matches were won by Gujarat Titans in a Super Over ?
# 2.How Many Matches won by Royal Challengers Bangalore Vs Kolkata Knight Riders.
# 3.How many Matches won by Toss Winner of the Match.
# 4.In how many matches was the result decided by the D/L method and the match was won by wickets?
# 5.In how many matches Toss won by Rajasthan Royals & Won the Match.
# 6.In how many matches V Kohli declared player of the match against Chennai Super Kings.
# 7.Which Team is the Toss Winner of the Final match Played in Dubai?
# 8.List out the Finals played by Kolkata Knight Riders in which Toss Won by Kolkata Knight Riders in the Finals and choose to
# ```
# field.tans.

# %%
import pandas as pd
data=pd.read_csv("ipl-matches.csv")
df=pd.DataFrame(data)
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
df.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
df["SuperOver"].unique()
# Out:
# array(['N', 'Y', nan], dtype=object)

# %%
df[(df["SuperOver"]=="Y")].shape[0]
# Out:
# 14

# %%
df[(df["WinningTeam"]=="Chennai Super Kings")&(df["City"]=="Kolkata")].shape[0]
# Out:
# 5

# %%
df[(df["Player_of_Match"]=="MS Dhoni")&((df["Team1"]=="Mumbai Indians")|(df["Team2"]=="Mumbai Indians"))].shape[0]
# Out:
# 1

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
g=nx.DiGraph()
g.add_nodes_from(["K","M","P"])
nx.draw_networkx(g)

# %%
routes=[
    (K,M),
    (M.P),
    (M,G),
    (K,D),
    (K,B),
    (M,D),
    (D,C),
    (D,S),
    (K,H),
    (H,C),
    (C,T)
]
g.add_edges_from(routes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[116], line 2
#       1 routes=[
# ----> 2     (K,M),
#       3     (M.P),
#       4     (M,G),
#       5     (K,D),
#       6     (K,B),
#       7     (M,D),
#       8     (D,C),
#       9     (D,S),
#      10     (K,H),
#      11     (H,C),
#      12     (C,T)
#      13 ]
#      14 g.add_edges_from(routes)
#
# NameError: name 'K' is not defined

# %%
plt.figure(figsize=(15,15))

# %%
px.scatter_matrix
# Out:
# <function plotly.express._chart_types.scatter_matrix(data_frame=None, dimensions=None, color=None, symbol=None, size=None, hover_name=None, hover_data=None, custom_data=None, category_orders=None, labels=None, color_discrete_sequence=None, color_discrete_map=None, color_continuous_scale=None, range_color=None, color_continuous_midpoint=None, symbol_sequence=None, symbol_map=None, opacity=None, size_max=None, title=None, template=None, width=None, height=None) -> plotly.graph_objs._figure.Figure>

# %%
import pandas as pd
df1 = pd.DataFrame({
 "ID":[1,2,3],
 "Name":["A","B","C"]
})
df2 = pd.DataFrame({
 "ID":[2,3,4],
 "Marks":[80,90,70]
})
result = pd.merge(df1, df2, how="inner", on="ID")
print(len(result))
# Out:
# 2
